# %%
import pandas as pd
import seaborn as sns
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
tables = pd.read_html("https://en.wikipedia.org/w/index.php?title=Moscow&oldid=683872744", header=1)

table = tables[4]
table
# Out:
#                                                  Year        Pop.       ±%
# 0                                                1897   1038625.0        —
# 1                                                1926   2019500.0   +94.4%
# 2                                                1939   4137000.0  +104.9%
# 3                                                1959   5032000.0   +21.6%
# 4                                                1970   6941961.0   +38.0%
# 5                                                1979   7830509.0   +12.8%
# 6                                                1989   8967332.0   +14.5%
# 7                                                2002  10382754.0   +15.8%
# 8                                                2010  11503501.0   +10.8%
# 9                                                2013  11794282.0    +2.5%
# 10                                               2015  12197596.0    +3.4%
# 11  Population size may be affected by changes in ...         NaN      NaN

# %%
table.drop(11, inplace=True)
table.Year=table.Year.astype(float)
table.plot(x='Year', y='Pop.')

# %%
sns.lmplot(x='Year', y='Pop.', data=table)

# %%
sns.lmplot(x='Year', y='Pop.', data=table, order=2)
